# %% [markdown]
# # Modelagem

# %% [markdown]
# Inicialmente, o conjunto de dados foi dividido em conjuntos de treinamento e teste por meio de amostragem estratificada. O conjunto de teste foi isolado antes de qualquer etapa de pré-processamento.
#
# Todas as etapas de transformação, balanceamento, seleção de algoritmo e ajuste de hiperparâmetros foram realizadas exclusivamente no conjunto de treinamento utilizando validação cruzada estratificada. O modelo final foi então treinado com todos os dados de treinamento e avaliado uma única vez no conjunto de teste.

# %% [markdown]
# ### Fluxograma do Pipeline de Dados
#
# ```text
#        ┌──────────────────────────────────────────┐
#        │     Dataset original (desbalanceado)     │
#        │            ~10.000 registros             │
#        └──────────────────────────────────────────┘
#                      │
#                      │ (Split estratificado)
#                      ▼
#        ┌──────────────────────────┐      ┌──────────────────────────────────────────┐
#        │     Conjunto de Teste    │      │         Conjunto de Treinamento          │
#        │   (~20% | ~2.000 reg.)   │◄─────┤           (~80% | ~8.000 reg.)           │
#        │  ❌ Sem pré-processamento │      └──────────────────────────────────────────┘
#        │  ❌ Sem balanceamento     │                    │
#        └─────────────┬────────────┘                    ▼
#                      │                 ┌──────────────────────────┐
#                      │                 │     Pré-processamento    │
#                      │                 │ (scaler, encoder, etc.)  │
#                      │                 │   ✔ fit apenas no treino │
#                      │                 └──────────────────────────┘
#                      │                                 │
#                      │                                 ▼
#                      │                 ┌──────────────────────────┐
#                      │                 │      Balanceamento       │
#                      │                 │          (Under)         │
#                      │                 │  ❗ apenas no treino     │
#                      │                 └──────────────────────────┘
#                      │                                 │
#                      │                                 ▼
#                      │                 ┌──────────────────────────┐
#                      │                 │     Validação Cruzada    │
#                      │                 │    (Stratified K-Fold)   │
#                      │                 │                          │
#                      │                 │ • Comparar algoritmos    │
#                      │                 │ • Ajustar hiperparâmetros│
#                      │                 │ • Estimar desempenho     │
#                      │                 └──────────────────────────┘
#                      │                                 │
#                      │                                 ▼
#                      │                 ┌──────────────────────────┐
#                      │                 │  Modelo final escolhido  │
#                      │                 │ (melhor algoritmo +      │
#                      │                 │   melhores parâmetros)   │
#                      │                 └──────────────────────────┘
#                      │                                 │
#                      │                                 ▼
#                      │                 ┌──────────────────────────┐
#                      │                 │     Treinamento final    │
#                      │                 │      (100% do treino)    │
#                      │                 │      ❌ sem CV           │
#                      │                 └──────────────────────────┘
#                      │                                 │
#                      ▼                                 ▼
#        ┌──────────────────────────────────────────────────────────┐
#        │                 Avaliação final no teste                 │
#        │ • Métricas reais (Precisão, AUC, curva ROC,              |
#        | sensibilidade e especificidade)                          │
#        │ • Validação de Generalização                             │
#        │ • Executado uma única vez                                │
#        └──────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Separando conjunto de teste e de treinamento

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

from utils.general import *
from utils.norm_test import *
from utils.pre_process import *
from utils.analise_estatistica  import *

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = catchPath('data/data.xlsx')
data_path
# Out:
# '/ML/data/data.xlsx'

# %%
df = pd.read_excel(data_path)
df.head()
# Out:
#    ID_Cliente Status_Cliente  Idade     Genero  Numero_Dependentes  \
# 0   768805383  Cliente Ativo     45  Masculino                   3
# 1   818770008  Cliente Ativo     49   Feminino                   5
# 2   713982108  Cliente Ativo     51  Masculino                   3
# 3   769911858  Cliente Ativo     40   Feminino                   4
# 4   709106358  Cliente Ativo     40  Masculino                   3
#
#      Nivel_Educacao   Estado_Civil   Faixa_Renda Categoria_Cartao  \
# 0      Ensino Médio         Casado     60k a 80k             Azul
# 1         Graduação       Solteiro  Menos de 40k             Azul
# 2         Graduação         Casado    80k a 120k             Azul
# 3      Ensino Médio  Não Informado  Menos de 40k             Azul
# 4  Sem Escolaridade         Casado     60k a 80k             Azul
#
#    Meses_Relacionamento  ...  Contatos_12m  Limite_Credito  Saldo_Rotativo  \
# 0                    39  ...             3         12691.0             777
# 1                    44  ...             2          8256.0             864
# 2                    36  ...             0          3418.0               0
# 3                    34  ...             1          3313.0            2517
# 4                    21  ...             0          4716.0               0
#
#    Limite_Disponivel  Variacao_Valor_Transacoes  Valor_Total_Transacoes  \
# 0            11914.0                      1.335                    1144
# 1             7392.0                      1.541                    1291
# 2             3418.0                      2.594                    1887
# 3              796.0                      1.405                    1171
# 4             4716.0                      2.175                     816
#
#    Quantidade_Transacoes  Variacao_Qtd_Transacoes  Taxa_Utilizacao_Credito  \
# 0                     42                    1.625                    0.061
# 1                     33                    3.714                    0.105
# 2                     20                    2.333                    0.000
# 3                     20                    2.333                    0.760
# 4                     28                    2.500                    0.000
#
#    classe
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (10127, 22)

# %% [markdown]
# ### Tabela Final de Decisão de Features
#
# | Variável | Evidência Estatística | Correlação | Decisão |
# |--|--|--|--|
# | Quantidade_Transacoes | Forte | Alta com Valor_Total | Manter |
# | Taxa_Utilizacao_Credito | Moderada | Baixa | Manter |
# | Meses_Inativos_12m | Moderada | Baixa | Manter |
# | Variacao_Qtd_Transacoes | Significativa | Baixa | Manter |
# | Variacao_Valor_Transacoes | Significativa | Baixa | Manter |
# | Valor_Total_Transacoes | Moderada | Alta | Substituir |
# | Limite_Credito | Fraca | Moderada | Opcional |
# | Idade | Não significativa | — | Remover |

# %%
df.columns
# Out:
# Index(['ID_Cliente', 'Status_Cliente', 'Idade', 'Genero', 'Numero_Dependentes',
#        'Nivel_Educacao', 'Estado_Civil', 'Faixa_Renda', 'Categoria_Cartao',
#        'Meses_Relacionamento', 'Total_Produtos', 'Meses_Inativos_12m',
#        'Contatos_12m', 'Limite_Credito', 'Saldo_Rotativo', 'Limite_Disponivel',
#        'Variacao_Valor_Transacoes', 'Valor_Total_Transacoes',
#        'Quantidade_Transacoes', 'Variacao_Qtd_Transacoes',
#        'Taxa_Utilizacao_Credito', 'classe'],
#       dtype='object')

# %%
features = [
    'Quantidade_Transacoes',
    'Taxa_Utilizacao_Credito',
    'Meses_Inativos_12m',
    'Variacao_Qtd_Transacoes',
    'Variacao_Valor_Transacoes'    
]

# %%
X = df[features].copy()
X.shape
# Out:
# (10127, 5)

# %%
y = df['classe'].copy()
y.shape
# Out:
# (10127,)

# %%
# split ANTES do balanceamento
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=2
)

# %%
X_test.shape
# Out:
# (2026, 5)

# %%
X_test.head()
# Out:
#       Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 2671                     39                    0.000                   0
# 1888                     61                    0.037                   4
# 6971                     49                    0.000                   4
# 9082                    106                    0.000                   3
# 5576                     68                    0.217                   1
#
#       Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes
# 2671                    0.345                      0.604
# 1888                    0.743                      0.889
# 6971                    1.227                      1.007
# 9082                    0.767                      0.947
# 5576                    0.700                      0.646

# %%
teste = X_test.copy()

# %%
teste['classe'] = y_test.copy()

# %%
y_test
# Out:
# 2671    0
# 1888    1
# 6971    1
# 9082    1
# 5576    1
#        ..
# 2286    1
# 550     1
# 857     1
# 9507    1
# 377     1
# Name: classe, Length: 2026, dtype: int64

# %%
teste.head()
# Out:
#       Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 2671                     39                    0.000                   0
# 1888                     61                    0.037                   4
# 6971                     49                    0.000                   4
# 9082                    106                    0.000                   3
# 5576                     68                    0.217                   1
#
#       Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 2671                    0.345                      0.604       0
# 1888                    0.743                      0.889       1
# 6971                    1.227                      1.007       1
# 9082                    0.767                      0.947       1
# 5576                    0.700                      0.646       1

# %%
teste.shape
# Out:
# (2026, 6)

# %%
SaveDataFrame(teste,'Grupo_teste')

# %%
treino = X_train.copy()

# %%
treino['classe'] = y_train.copy()

# %%
treino.head()
# Out:
#       Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 2607                     52                    0.619                   1
# 5418                     50                    0.000                   3
# 2684                     73                    0.036                   2
# 1345                     42                    0.000                   1
# 4298                     39                    0.000                   2
#
#       Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 2607                    0.857                      0.612       1
# 5418                    0.923                      0.602       0
# 2684                    0.698                      0.739       1
# 1345                    0.750                      0.782       1
# 4298                    0.345                      0.637       0

# %%
treino.shape
# Out:
# (8101, 6)

# %%
SaveDataFrame(treino,'Grupo_treino')

# %%
# determinando o nivel de confiança para a amostra de teste com um erro de 2%
df_validacao = calcular_confianca_amostral(N=10127, n=2026, e=0.02)
print(df_validacao)
# Out:
#                 Parâmetro          Valor
# 0     População Total (N)         10.127
# 1  Tamanho da Amostra (n)  2.026 (20.0%)
# 2      Margem de Erro (e)           2.0%
# 3      Escore-Z calculado           2.01
# 4      Nível de Confiança          95.6%

# %% [markdown]
# A amostragem para construir o conjunto de dados para realizar os testes foi validado estatisticamente demonstrando representatividade. Para uma população total de $N = 10.127$, a amostra de teste selecionada de $n = 2.026$ (20% do dataset) resulta em um nível de confiança de aproximadamente 95,5%, com uma margem de erro estrita de apenas 2%.

# %% [markdown]
# # Balanceamento

# %%
path_treino = catchPath('data/Grupo_treino.xlsx')
path_treino
# Out:
# '/ML/data/Grupo_treino.xlsx'

# %%
df2 = pd.read_excel(path_treino)
df2.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     52                    0.619                   1
# 1                     50                    0.000                   3
# 2                     73                    0.036                   2
# 3                     42                    0.000                   1
# 4                     39                    0.000                   2
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 0                    0.857                      0.612       1
# 1                    0.923                      0.602       0
# 2                    0.698                      0.739       1
# 3                    0.750                      0.782       1
# 4                    0.345                      0.637       0

# %%
df2.columns
# Out:
# Index(['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
#        'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
#        'Variacao_Valor_Transacoes', 'classe'],
#       dtype='object')

# %%
col = ['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
       'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
       'Variacao_Valor_Transacoes']

# %%
x1 = df2[col].copy()

# %%
x1.shape
# Out:
# (8101, 5)

# %%
y1 = df2['classe'].copy()

# %%
y1.shape
# Out:
# (8101,)

# %%
y1.value_counts()
# Out:
# classe
# 1    6799
# 0    1302
# Name: count, dtype: int64

# %%
X_resampled, y_resampled = balances_categories(x1, y1)

# %%
X_resampled.shape
# Out:
# (2604, 5)

# %%
y_resampled.value_counts()
# Out:
# classe
# 0    1302
# 1    1302
# Name: count, dtype: int64

# %%
df_balance = X_resampled.copy()
df_balance.head()
# Out:
#     Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 1                      50                    0.000                   3
# 4                      39                    0.000                   2
# 13                     40                    0.000                   3
# 30                     47                    0.000                   2
# 38                     44                    0.983                   2
#
#     Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes
# 1                     0.923                      0.602
# 4                     0.345                      0.637
# 13                    0.212                      0.399
# 30                    0.469                      0.367
# 38                    0.467                      0.850

# %%
df_balance['classe'] = y_resampled
df_balance.head()
# Out:
#     Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 1                      50                    0.000                   3
# 4                      39                    0.000                   2
# 13                     40                    0.000                   3
# 30                     47                    0.000                   2
# 38                     44                    0.983                   2
#
#     Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 1                     0.923                      0.602       0
# 4                     0.345                      0.637       0
# 13                    0.212                      0.399       0
# 30                    0.469                      0.367       0
# 38                    0.467                      0.850       0

# %%
SaveDataFrame(df_balance,'Grupo_treino_Balanceado')

# %%
df_balance.shape
# Out:
# (2604, 6)

# %%
# determinando o nivel de confiança para a amostra de teste com um erro de 2%
df_validacao = calcular_confianca_amostral(N=8101, n=2604, e=0.02)
print(df_validacao)
# Out:
#                 Parâmetro          Valor
# 0     População Total (N)          8.101
# 1  Tamanho da Amostra (n)  2.604 (32.1%)
# 2      Margem de Erro (e)           2.0%
# 3      Escore-Z calculado           2.48
# 4      Nível de Confiança          98.7%

# %% [markdown]
# Optou-se pelo do metodo de under sampling, e obtivemos um grupo de treinamento  com classes balanceadas com um total de 2604 registros, essa nova subamostragem é representativa com uma margem de erro de 2% com nivel de confiança de 98,7%.

# %% [markdown]
# # Escolha dos métodos de Machine Learning

# %%
path_t_balance = catchPath('data/Grupo_treino_Balanceado.xlsx')
path_t_balance
# Out:
# '/ML/data/Grupo_treino_Balanceado.xlsx'

# %%
df3 =  pd.read_excel(path_t_balance)
df3.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     50                    0.000                   3
# 1                     39                    0.000                   2
# 2                     40                    0.000                   3
# 3                     47                    0.000                   2
# 4                     44                    0.983                   2
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 0                    0.923                      0.602       0
# 1                    0.345                      0.637       0
# 2                    0.212                      0.399       0
# 3                    0.469                      0.367       0
# 4                    0.467                      0.850       0

# %%
df3.shape
# Out:
# (2604, 6)

# %%
df3['classe'].value_counts()
# Out:
# classe
# 0    1302
# 1    1302
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import cross_validate, KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# 1. Configuração inicial
modelos_nomes = ['naive_bayes', 'logistica', 'forest', 'svm']
resultados = {nome: {'acc': [], 'auc': []} for nome in modelos_nomes}
metrics = ['accuracy', 'roc_auc']

# %%
df3.columns
# Out:
# Index(['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
#        'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
#        'Variacao_Valor_Transacoes', 'classe'],
#       dtype='object')

# %%
c = ['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
       'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
       'Variacao_Valor_Transacoes']

# %%
X = df3[c].copy()

# %%
X.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     50                    0.000                   3
# 1                     39                    0.000                   2
# 2                     40                    0.000                   3
# 3                     47                    0.000                   2
# 4                     44                    0.983                   2
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes
# 0                    0.923                      0.602
# 1                    0.345                      0.637
# 2                    0.212                      0.399
# 3                    0.469                      0.367
# 4                    0.467                      0.850

# %%
y = df3['classe'].copy()

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: classe, dtype: int64

# %%
X.shape
# Out:
# (2604, 5)

# %%
y.shape
# Out:
# (2604,)

# %%
# 2. Loop de Processamento (30 rodadas)
for i in range(30):
    kfold = KFold(n_splits=10, shuffle=True, random_state=i)

    lista_modelos = [
        ('naive_bayes', GaussianNB()),
        ('logistica', Pipeline([('scaler', StandardScaler()), ('model', LogisticRegression(max_iter=1000))])),
        ('forest', RandomForestClassifier()),
        ('svm', Pipeline([('scaler', StandardScaler()), ('model', SVC(probability=True))]))
    ]

    for nome, modelo in lista_modelos:
        scores = cross_validate(modelo, X, y, cv=kfold, scoring=metrics)
        resultados[nome]['acc'].append(scores['test_accuracy'].mean())
        resultados[nome]['auc'].append(scores['test_roc_auc'].mean())

# %%
# 3. Compilando o resultado em um dataframe 
df_completo = pd.DataFrame({
    (mod, met): resultados[mod][met]
    for mod in resultados.keys()
    for met in resultados[mod].keys()
})
df_completo.columns = pd.MultiIndex.from_tuples(df_completo.columns, names=['Modelo', 'Métrica'])

# %%
df_completo.head()
# Out:
# Modelo  naive_bayes           logistica              forest            \
# Métrica         acc       auc       acc       auc       acc       auc
# 0          0.789195  0.868364  0.782278  0.858591  0.842953  0.914913
# 1          0.791870  0.868927  0.781116  0.859281  0.841410  0.913341
# 2          0.793425  0.869481  0.779592  0.858388  0.836040  0.912963
# 3          0.793416  0.868201  0.781505  0.857846  0.837567  0.914166
# 4          0.790321  0.868641  0.781872  0.858915  0.837548  0.913440
#
# Modelo        svm
# Métrica       acc       auc
# 0        0.833733  0.907501
# 1        0.834499  0.906602
# 2        0.836804  0.907149
# 3        0.835644  0.906715
# 4        0.837552  0.908136

# %%
df_completo.mean()
# Out:
# Modelo       Métrica
# naive_bayes  acc        0.791236
#              auc        0.868958
# logistica    acc        0.780840
#              auc        0.859025
# forest       acc        0.839429
#              auc        0.914873
# svm          acc        0.835205
#              auc        0.907973
# dtype: float64

# %%
# 4. Exportação para Excel

df_estatisticas = df_completo.describe()

with pd.ExcelWriter('resultados_machine_learning.xlsx') as writer:
    df_completo.to_excel(writer, sheet_name='Dados_Brutos_30_Rodadas')
    df_estatisticas.to_excel(writer, sheet_name='Resumo_Estatistico')

print("Arquivo 'resultados_machine_learning.xlsx' gerado com sucesso!")
# Out:
# Arquivo 'resultados_machine_learning.xlsx' gerado com sucesso!

# %%
df_completo = pd.DataFrame({
    ('Naive Bayes', 'ACC'): resultados['naive_bayes']['acc'],
    ('Naive Bayes', 'AUC'): resultados['naive_bayes']['auc'],
    ('Logística', 'ACC'): resultados['logistica']['acc'],
    ('Logística', 'AUC'): resultados['logistica']['auc'],
    ('Forest', 'ACC'): resultados['forest']['acc'],
    ('Forest', 'AUC'): resultados['forest']['auc'],
    ('SVM', 'ACC'): resultados['svm']['acc'],
    ('SVM', 'AUC'): resultados['svm']['auc']
}) #padronizando os rótolos

# 2. 
df_completo.columns = pd.MultiIndex.from_tuples(df_completo.columns, names=['Modelo', 'Métrica'])

# 3. 
import seaborn as sns
import matplotlib.pyplot as plt

df_medias = df_completo.mean().unstack()

fig, ax = plt.subplots(1, 2, figsize=(16, 6))

# Calor (Média)
sns.heatmap(df_medias, annot=True, cmap='YlGnBu', fmt='.4f', ax=ax[0])
ax[0].set_title('Média de Performance (ACC vs AUC)')

# Boxplot (Variação) - 
df_auc_only = df_completo.xs('AUC', axis=1, level='Métrica')
sns.boxplot(data=df_auc_only, ax=ax[1], palette='Set2')
ax[1].set_title('Variabilidade do AUC (30 Rodadas)')

plt.tight_layout()
plt.show()

# %%
df_completo.head()
# Out:
# Modelo  Naive Bayes           Logística              Forest            \
# Métrica         ACC       AUC       ACC       AUC       ACC       AUC
# 0          0.789195  0.868364  0.782278  0.858591  0.842953  0.914913
# 1          0.791870  0.868927  0.781116  0.859281  0.841410  0.913341
# 2          0.793425  0.869481  0.779592  0.858388  0.836040  0.912963
# 3          0.793416  0.868201  0.781505  0.857846  0.837567  0.914166
# 4          0.790321  0.868641  0.781872  0.858915  0.837548  0.913440
#
# Modelo        SVM
# Métrica       ACC       AUC
# 0        0.833733  0.907501
# 1        0.834499  0.906602
# 2        0.836804  0.907149
# 3        0.835644  0.906715
# 4        0.837552  0.908136

# %%
df_estatisticas = df_completo.describe()

with pd.ExcelWriter('resultados_machine_learning_.xlsx') as writer:
    df_completo.to_excel(writer, sheet_name='Dados_Brutos_30_Rodadas')
    df_estatisticas.to_excel(writer, sheet_name='Resumo_Estatistico')

print("Arquivo 'resultados_machine_learning.xlsx' gerado com sucesso!")
# Out:
# Arquivo 'resultados_machine_learning.xlsx' gerado com sucesso!

# %%
# Filtramos apenas as colunas de AUC
df_auc = df_completo.xs('AUC', axis=1, level='Métrica')
# Out:
#             Estatística   p-valor Distribuição Normal?
# Naive Bayes    0.981965  0.875041                  Sim
# Logística      0.971768  0.588605                  Sim
# Forest         0.984453   0.92752                  Sim
# SVM            0.973894  0.650176                  Sim

# %%
df_auc.head()
# Out:
# Modelo  Naive Bayes  Logística    Forest       SVM
# 0          0.868364   0.858591  0.914913  0.907501
# 1          0.868927   0.859281  0.913341  0.906602
# 2          0.869481   0.858388  0.912963  0.907149
# 3          0.868201   0.857846  0.914166  0.906715
# 4          0.868641   0.858915  0.913440  0.908136

# %%
df_auc.shape
# Out:
# (30, 4)

# %%
df_auc.mean()
# Out:
# Modelo
# Naive Bayes    0.868958
# Logística      0.859025
# Forest         0.914873
# SVM            0.907973
# dtype: float64

# %%
df_auc.std()
# Out:
# Modelo
# Naive Bayes    0.000590
# Logística      0.000638
# Forest         0.000928
# SVM            0.000890
# dtype: float64

# %%
SaveDataFrame(df_auc,'Resultados_Modelos_Metrica_AUC')

# %%
# Filtramos apenas as colunas de ACC
df_acc = df_completo.xs('ACC', axis=1, level='Métrica')
df_acc.head()
# Out:
# Modelo  Naive Bayes  Logística    Forest       SVM
# 0          0.789195   0.782278  0.842953  0.833733
# 1          0.791870   0.781116  0.841410  0.834499
# 2          0.793425   0.779592  0.836040  0.836804
# 3          0.793416   0.781505  0.837567  0.835644
# 4          0.790321   0.781872  0.837548  0.837552

# %%
df_acc.mean()
# Out:
# Modelo
# Naive Bayes    0.791236
# Logística      0.780840
# Forest         0.839429
# SVM            0.835205
# dtype: float64

# %%
df_acc.std()
# Out:
# Modelo
# Naive Bayes    0.001253
# Logística      0.001111
# Forest         0.002336
# SVM            0.001545
# dtype: float64

# %%
SaveDataFrame(df_acc,'Resultados_Modelos_Metrica_ACC')

# %% [markdown]
# ### Testando Normalidade

# %%
from scipy.stats import shapiro
import pandas as pd

def testar_normalidade(df, metrica='AUC'):
    """
    Realiza o teste de Shapiro-Wilk para todos os modelos de uma métrica específica.
    """
    # 1. Extrai apenas a métrica desejada usando cross-section (xs)
    try:
        dados_metrica = df.xs(metrica, axis=1, level='Métrica')
    except KeyError:
        return f"Erro: A métrica '{metrica}' não foi encontrada no DataFrame."

    resultados = []

    # 2. Loop pelos modelos (colunas)
    for modelo in dados_metrica.columns:
        stat, p_valor = shapiro(dados_metrica[modelo])
        
        # Interpretando o p-valor (alfa de 0.05)
        dist_normal = "Sim" if p_valor > 0.05 else "Não"
        
        resultados.append({
            'Modelo': modelo,
            'Métrica': metrica,
            'Estatística W': round(stat, 4),
            'p-valor': round(p_valor, 4),
            'Normal?': dist_normal
        })

    # 3. Retorna um DataFrame organizado
    return pd.DataFrame(resultados).set_index('Modelo')

# %%
# Para AUC
df_norm_auc = testar_normalidade(df_completo, metrica='AUC')
print("Teste de Normalidade para AUC:")
print(df_norm_auc)

print("\n" + "-"*30 + "\n")
# Out:
# Teste de Normalidade para AUC:
#             Métrica  Estatística W  p-valor Normal?
# Modelo
# Naive Bayes     AUC         0.9820   0.8750     Sim
# Logística       AUC         0.9718   0.5886     Sim
# Forest          AUC         0.9845   0.9275     Sim
# SVM             AUC         0.9739   0.6502     Sim
#
# ------------------------------

# %%
# Para ACC
df_norm_acc = testar_normalidade(df_completo, metrica='ACC')
print("Teste de Normalidade para ACC:")
print(df_norm_acc)
# Out:
# Teste de Normalidade para ACC:
#             Métrica  Estatística W  p-valor Normal?
# Modelo
# Naive Bayes     ACC         0.9683   0.4933     Sim
# Logística       ACC         0.9621   0.3503     Sim
# Forest          ACC         0.9738   0.6469     Sim
# SVM             ACC         0.9708   0.5607     Sim

# %%
from scipy import stats

def executar_anova_auc(caminho_arquivo):
    """
    Responsabilidade: Carregar os dados de AUC e calcular a ANOVA de uma via.
    """
    # Carrega os dados (considerando que o CSV veio do seu Excel de AUC)
    df = pd.read_excel(caminho_arquivo)
    
    # Prepara os grupos: cada coluna vira uma lista de valores para o teste
    # Ex: grupos = [coluna_NB, coluna_Log, coluna_Forest, coluna_SVM]
    grupos = [df[coluna].values for coluna in df.columns]
    
    # Calcula a ANOVA de uma via (One-way ANOVA)
    f_stat, p_valor = stats.f_oneway(*grupos)
    
    return f_stat, p_valor

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

def executar_tukey_auc(caminho_arquivo, alfa=0.05):
    """
    Responsabilidade: Transformar os dados para formato longo e 
    realizar a comparação par a par de Tukey.
    """
    # 1. Carrega os dados originais (formato largo)
    df = pd.read_excel(caminho_arquivo)
    
    # 2. Transforma para formato longo (necessário para o statsmodels)
    # De: [NB, Log, Forest] -> Para: [Modelo, Valor]
    df_longo = df.melt(var_name='Modelo', value_name='AUC')
    
    # 3. Realiza o teste de Tukey
    resultado_tukey = pairwise_tukeyhsd(endog=df_longo['AUC'], 
                                        groups=df_longo['Modelo'], 
                                        alpha=alfa)
    
    return resultado_tukey

# %%
arquivo = catchPath('data/Resultados_Modelos_Metrica_AUC.xlsx')
arquivo
# Out:
# '/ML/data/Resultados_Modelos_Metrica_AUC.xlsx'

# %%
executar_anova_auc

# %%
# Passo 1: Avaliar se há diferença global
f, p = executar_anova_auc(arquivo)

print(f"=== RESULTADO ANOVA ===")
print(f"p-valor: {p:.4e}")

if p < 0.05:
    print("\n[!] Diferença significativa detectada. Iniciando Teste de Tukey...\n")
    # Passo 2: Comparação par a par
    resultado_final = executar_tukey_auc(arquivo)
    print(resultado_final)
else:
    print("\n[✓] Não há diferença estatística entre os modelos (p >= 0.05).")
# Out:
# === RESULTADO ANOVA ===
# p-valor: 9.3110e-174
#
# [!] Diferença significativa detectada. Iniciando Teste de Tukey...
#
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =============================================================
#    group1      group2   meandiff p-adj  lower   upper  reject
# -------------------------------------------------------------
#      Forest   Logística  -0.0558   0.0 -0.0564 -0.0553   True
#      Forest Naive Bayes  -0.0459   0.0 -0.0464 -0.0454   True
#      Forest         SVM  -0.0069   0.0 -0.0074 -0.0064   True
#   Logística Naive Bayes   0.0099   0.0  0.0094  0.0105   True
#   Logística         SVM   0.0489   0.0  0.0484  0.0495   True
# Naive Bayes         SVM    0.039   0.0  0.0385  0.0395   True
# -------------------------------------------------------------

# %% [markdown]
# A análise estatística através do teste de Tukey (com $\alpha=0.05$) confirmou que o modelo Random Forest apresentou o melhor desempenho de classificação (AUC médio de 0.914), superando de forma estatisticamente significativa todos os demais algoritmos testados ($p < 0.001$). O modelo SVM consolidou-se como a segunda melhor opção, enquanto a Regressão Logística apresentou o menor desempenho médio entre os candidatos.

# %% [markdown]
# # Ajuste dos Hiperparâmetros

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
data_path = catchPath('data/Grupo_treino_Balanceado.xlsx')
data_path
# Out:
# '/ML/data/Grupo_treino_Balanceado.xlsx'

# %%
df4 = pd.read_excel(data_path)
df4.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     50                    0.000                   3
# 1                     39                    0.000                   2
# 2                     40                    0.000                   3
# 3                     47                    0.000                   2
# 4                     44                    0.983                   2
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 0                    0.923                      0.602       0
# 1                    0.345                      0.637       0
# 2                    0.212                      0.399       0
# 3                    0.469                      0.367       0
# 4                    0.467                      0.850       0

# %%
df4.columns
# Out:
# Index(['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
#        'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
#        'Variacao_Valor_Transacoes', 'classe'],
#       dtype='object')

# %%
c = ['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
       'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
       'Variacao_Valor_Transacoes']

# %%
X_dev = df4[c].copy()

# %%
X_dev.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     50                    0.000                   3
# 1                     39                    0.000                   2
# 2                     40                    0.000                   3
# 3                     47                    0.000                   2
# 4                     44                    0.983                   2
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes
# 0                    0.923                      0.602
# 1                    0.345                      0.637
# 2                    0.212                      0.399
# 3                    0.469                      0.367
# 4                    0.467                      0.850

# %%
X_dev.shape
# Out:
# (2604, 5)

# %%
y_dev = df4['classe'].copy()
y_dev.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: classe, dtype: int64

# %%
y_dev.shape
# Out:
# (2604,)

# %%
# 1. Construção do Pipeline
# O nome 'model' será usado como prefixo para os parâmetros no Grid Search
pipeline_rf = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier(random_state=2))
])

# %%
# 2. Definição do Grid de Parâmetros

param_grid = {
    'model__n_estimators': [100, 200, 300],
    'model__max_depth': [None, 10, 20],
    'model__min_samples_split': [2, 5],
    'model__min_samples_leaf': [1, 2],
    'model__bootstrap': [True]
}

# %%
# 3. Configuração do Grid Search
# cv=5: Validação cruzada em 5 dobras para cada combinação
# n_jobs=-1: Usa todos os núcleos do seu processador (muito mais rápido)
grid_search = GridSearchCV(
    estimator=pipeline_rf,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=2
)

# %%
# 4. Execução (Treinamento)
print("Iniciando busca exaustiva (Grid Search)...")
grid_search.fit(X_dev, y_dev)
# Out:
# Iniciando busca exaustiva (Grid Search)...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.9s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=None, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=1, model__min_samples_split=5, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=2, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=200; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=20, model__min_samples_leaf=2, model__min_samples_split=5, model__n_estimators=300; total time=   0.7s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model',
#                                         RandomForestClassifier(random_state=2))]),
#              param_grid={'model__bootstrap': [True],
#                          'model__max_depth': [None, 10, 20],
#                          'model__min_samples_leaf': [1, 2],
#                          'model__min_samples_split': [2, 5],
#                          'model__n_estimators': [100, 200, 300]},
#              scoring='roc_auc', verbose=2)

# %%
# 5. Exibição dos Resultados
print("\n" + "="*30)
print(f"Melhor AUC (Validação): {grid_search.best_score_:.4f}")
print("Melhores Parâmetros encontrados:")
for param, value in grid_search.best_params_.items():
    print(f"- {param.replace('model__', '')}: {value}")
print("="*30)
# Out:
# ==============================
# Melhor AUC (Validação): 0.9179
# Melhores Parâmetros encontrados:
# - bootstrap: True
# - max_depth: 10
# - min_samples_leaf: 2
# - min_samples_split: 5
# - n_estimators: 200
# ==============================

# %% [markdown]
# # Treinamento

# %%
# Criamos o Pipeline final 

pipeline_final = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier(
        n_estimators=200,      
        max_depth=10,          
        min_samples_leaf=2,    
        min_samples_split=5,   
        bootstrap=True,        
        random_state=2        
    ))
])

# %%
# TREINO: O Scaler aprende a média de X_dev e o Modelo aprende os pesos
pipeline_final.fit(X_dev, y_dev)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  RandomForestClassifier(max_depth=10, min_samples_leaf=2,
#                                         min_samples_split=5, n_estimators=200,
#                                         random_state=2))])

# %%
import joblib

def salvando_modelo(pepiline, nome):

    n = 'data/' + nome + '.joblib'
    p = catchPath(n)
    
    joblib.dump(pepiline, p)
    
    print(f"Modelo salvo com sucesso em: {p}")

# %%
salvando_modelo(pipeline_final, 'pipeline_random_forest_final')
# Out:
# Modelo salvo com sucesso em: /ML/data/pipeline_random_forest_final.joblib

# %%
# --- Como carregar depois ---
# modelo_carregado = joblib.load('pipeline_random_forest_final.joblib')

# %% [markdown]
# # Avaliando o desempenho do Modelo

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
import pandas as pd
import joblib

# %%
teste_path = catchPath('data/Grupo_teste.xlsx')
teste_path
# Out:
# '/ML/data/Grupo_teste.xlsx'

# %%
df_teste = pd.read_excel(teste_path)
df_teste.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     39                    0.000                   0
# 1                     61                    0.037                   4
# 2                     49                    0.000                   4
# 3                    106                    0.000                   3
# 4                     68                    0.217                   1
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 0                    0.345                      0.604       0
# 1                    0.743                      0.889       1
# 2                    1.227                      1.007       1
# 3                    0.767                      0.947       1
# 4                    0.700                      0.646       1

# %%
df_teste.shape
# Out:
# (2026, 6)

# %%
df_teste['classe'].value_counts()
# Out:
# classe
# 1    1701
# 0     325
# Name: count, dtype: int64

# %%
modelo_path = catchPath('data/pipeline_random_forest_final.joblib')
modelo_path
# Out:
# '/ML/data/pipeline_random_forest_final.joblib'

# %%
#carregando o modelo
pipeline_final = joblib.load(modelo_path)

# %%
c = ['Quantidade_Transacoes', 'Taxa_Utilizacao_Credito',
       'Meses_Inativos_12m', 'Variacao_Qtd_Transacoes',
       'Variacao_Valor_Transacoes']

# %%
X_teste_final = df_teste[c].copy()
X_teste_final.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     39                    0.000                   0
# 1                     61                    0.037                   4
# 2                     49                    0.000                   4
# 3                    106                    0.000                   3
# 4                     68                    0.217                   1
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes
# 0                    0.345                      0.604
# 1                    0.743                      0.889
# 2                    1.227                      1.007
# 3                    0.767                      0.947
# 4                    0.700                      0.646

# %%
y_teste_final = df_teste['classe'].copy()
y_teste_final.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: classe, dtype: int64

# %%
# Predições no teste final
y_pred_final = pipeline_final.predict(X_teste_final)
y_prob_final = pipeline_final.predict_proba(X_teste_final)[:, 1]

# %%
# Métricas Finais
acc_final = metrics.accuracy_score(y_teste_final, y_pred_final)
auc_final = metrics.roc_auc_score(y_teste_final, y_prob_final)

# %%
print(f"Resultado Final no Teste - ACC: {acc_final:.4f}, AUC: {auc_final:.4f}")
# Out:
# Resultado Final no Teste - ACC: 0.8356, AUC: 0.9149

# %%
confusion = metrics.confusion_matrix(y_teste_final, y_pred_final)
TP = confusion[1,1]
TN = confusion[0,0]
FP = confusion[0,1]
FN = confusion[1,0]

# %%
# Calculando a sensibilidade
print(TP/(TP+FN))
print(metrics.recall_score(y_teste_final, y_pred_final))
# Out:
# 0.8365667254556144
# 0.8365667254556144

# %%
# Calculando a especificidade
print(TN/(TN+FP))
# Out:
# 0.8307692307692308

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_teste_final, y_prob_final)

# %%
sns.lineplot(x=fpr, y=tpr).set(title='Curva ROC')
plt.ylim(0, 1)
plt.xlim(0, 1)
#plt.savefig('Roc_curve_ECFP6.png',dpi = 300)
# Out:
# (0.0, 1.0)

# %%
from sklearn.metrics import ConfusionMatrixDisplay


plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=['Classe 0', 'Classe 1'])
disp.plot(cmap='Blues', values_format='d')

plt.title('Matriz de Confusão Final - Random Forest')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import numpy as np

# 1. Calcular precisão e recall para todos os limiares possíveis
precisions, recalls, thresholds = precision_recall_curve(y_teste_final, y_prob_final)

# 2. Calcular o F1-Score para cada limiar

f1_scores = 2 * (precisions * recalls) / (precisions + recalls)
best_threshold = thresholds[np.argmax(f1_scores)]

print(f"O melhor limiar para equilibrar o modelo é: {best_threshold:.4f}")
# Out:
# O melhor limiar para equilibrar o modelo é: 0.1744

# %%
# 3. Plotar a Curva
plt.figure(figsize=(8, 5))
plt.plot(thresholds, precisions[:-1], "b--", label="Precisão")
plt.plot(thresholds, recalls[:-1], "g-", label="Recall (Sensibilidade)")
plt.axvline(best_threshold, color="red", linestyle=":", label=f"Melhor Limiar ({best_threshold:.2f})")
plt.xlabel("Limiar (Threshold)")
plt.legend()
plt.title("Equilíbrio Precisão vs Recall")
plt.show()

# %%
# Aplicando o novo limiar encontrado
y_pred_otimizado = (y_prob_final >= best_threshold).astype(int)

# %%
# Nova Matriz de Confusão
from sklearn.metrics import confusion_matrix
cm_final = confusion_matrix(y_teste_final, y_pred_otimizado)

# %%
print("Nova Matriz de Confusão Otimizada:")
print(cm_final)
# Out:
# Nova Matriz de Confusão Otimizada:
# [[ 178  147]
#  [  53 1648]]

# %%
limiar_rigoroso = 0.65 

y_pred_churn = (y_prob_final >= limiar_rigoroso).astype(int)

# %%
# Nova matriz focada em reduzir a falha de detecção de Churn
from sklearn.metrics import confusion_matrix
cm_churn = confusion_matrix(y_teste_final, y_pred_churn)

# %%
cm_churn
# Out:
# array([[ 290,   35],
#        [ 425, 1276]])

# %%
acc_final_churn = metrics.accuracy_score(y_teste_final, y_pred_churn)

# %%
def calc_sensibilidade(y_teste, y_pred):
    
    confusion = metrics.confusion_matrix(y_teste, y_pred)
    TP = confusion[1,1]
    TN = confusion[0,0]
    FP = confusion[0,1]
    FN = confusion[1,0]
    # Calculando a sensibilidade
    s = TP/(TP+FN)
    return s

# %%
def calc_especificidade(y_teste, y_pred):
    
    confusion = metrics.confusion_matrix(y_teste, y_pred)
    TP = confusion[1,1]
    TN = confusion[0,0]
    FP = confusion[0,1]
    FN = confusion[1,0]
    # Calculando a especificidade
    e = TN/(TN+FP)
    return e

# %%
s_churn = calc_sensibilidade(y_teste_final, y_pred_churn)
print(f'sensibilidade do modelo ajustado: {s_churn:.2f}')
# Out:
# 0.7501469723691946
# sensibilidade do modelo ajustado: 0.75

# %%
e_churn = calc_especificidade(y_teste_final, y_pred_churn)
print(f'especificidade do modelo ajustado: {e_churn:.2f}')
# Out:
# especificidade do modelo ajustado: 0.89

# %% [markdown]
# ### Comparativo Operacional: Modelo Original vs. Modelo Ajustado (Churn)
#
# | Métrica | Modelo A (Equilibrado) | Modelo B (Estratégico/Atual) | Interpretação de Negócio |
# | :--- | :---: | :---: | :--- |
# | **Acurácia (Geral)** | 83.6% | **77.3%** | Taxa global de acerto do modelo. |
# | **Especificidade (Churn)** | 83.0% | **89.2%** | Capacidade de capturar clientes que vão sair (Classe 0). |
# | **Sensibilidade (Ativos)** | 83.7% | **75.0%** | Capacidade de identificar clientes que permanecem (Classe 1). |
# | **Falsos Positivos** | 55 | **35** | Clientes que saíram sem o modelo detectar (Risco). |
# | **Falsos Negativos** | 278 | 425 | Alarmes falsos (Custo de ações de marketing). |

# %% [markdown]
# Análise Estratégica de Performance: A transição para o Modelo B (Estratégico) reflete uma decisão orientada ao negócio de retenção. Ao priorizarmos a Especificidade (89,2%), aumentamos significativamente nossa capacidade de identificar clientes em risco de evasão, reduzindo em 36% o número de "fujões" não detectados (Falsos Positivos caíram de 55 para 35). Embora essa escolha implique em uma redução na Acurácia Geral e na Sensibilidade dos Ativos, o custo operacional de realizar ações preventivas em clientes ativos (Falsos Negativos) é considerado inferior ao valor do Customer Lifetime Value (LTV) recuperado ao evitar o Churn real.

# %% [markdown]
# ### Simulando o uso do modelo em produção
#
# Essa etapa é apenas uma simulação do uso do modelo em produção

# %%
# Carregar o grupo de teste
df_simulacao = df_teste.copy()
df_simulacao.head()
# Out:
#    Quantidade_Transacoes  Taxa_Utilizacao_Credito  Meses_Inativos_12m  \
# 0                     39                    0.000                   0
# 1                     61                    0.037                   4
# 2                     49                    0.000                   4
# 3                    106                    0.000                   3
# 4                     68                    0.217                   1
#
#    Variacao_Qtd_Transacoes  Variacao_Valor_Transacoes  classe
# 0                    0.345                      0.604       0
# 1                    0.743                      0.889       1
# 2                    1.227                      1.007       1
# 3                    0.767                      0.947       1
# 4                    0.700                      0.646       1

# %%
def motor_de_decisao_producao(prob_ativo, limiar=0.65):
    """
    Classifica e sugere ação baseada na probabilidade de ser ATIVO.
    """
    score_risco = (1 - prob_ativo) * 100
    
    if prob_ativo < limiar:
        classe_predita = "Churn (Risco)"
        if score_risco > 80:
            acao = "CRÍTICO: Contato Humano Imediato"
        else:
            acao = "ALTO: Oferta de Retenção (Cupom)"
    else:
        classe_predita = "Ativo (Seguro)"
        acao = "Monitoramento Padrão"
        
    return classe_predita, score_risco, acao

# %%
# 1. Separar as features (removendo a coluna 'classe' original para simular dados novos)
X_novos = df_simulacao.drop(columns=['classe'])

# 2. Obter as probabilidades do modelo (Classe 1 = Ativo)
probs_ativos = pipeline_final.predict_proba(X_novos)[:, 1]

# %%
# 3. Aplicar a lógica de decisão para cada linha
resultados = []
for i, prob in enumerate(probs_ativos):
    classe, score, acao = motor_de_decisao_producao(prob)
    resultados.append({
        'Cliente_ID': i + 1,
        'Prob_Ativo': round(prob, 4),
        'Score_Risco_Churn (%)': round(score, 2),
        'Predicao_Final': classe,
        'Acao_Recomendada': acao
    })

# %%
# 4. Criar o DataFrame de saída
df_resultado_final = pd.DataFrame(resultados)

# Exibir os primeiros 10 clientes da simulação
display(df_resultado_final.head(10))
# Out:
#    Cliente_ID  Prob_Ativo  Score_Risco_Churn (%)  Predicao_Final  \
# 0           1      0.0867                  91.33   Churn (Risco)
# 1           2      0.4259                  57.41   Churn (Risco)
# 2           3      0.3185                  68.15   Churn (Risco)
# 3           4      0.7930                  20.70  Ativo (Seguro)
# 4           5      0.9385                   6.15  Ativo (Seguro)
# 5           6      0.5107                  48.93   Churn (Risco)
# 6           7      0.1834                  81.66   Churn (Risco)
# 7           8      0.9485                   5.15  Ativo (Seguro)
# 8           9      0.2031                  79.69   Churn (Risco)
# 9          10      0.9244                   7.56  Ativo (Seguro)
#
#                    Acao_Recomendada
# 0  CRÍTICO: Contato Humano Imediato
# 1  ALTO: Oferta de Retenção (Cupom)
# 2  ALTO: Oferta de Retenção (Cupom)
# 3              Monitoramento Padrão
# 4              Monitoramento Padrão
# 5  ALTO: Oferta de Retenção (Cupom)
# 6  CRÍTICO: Contato Humano Imediato
# 7              Monitoramento Padrão
# 8  ALTO: Oferta de Retenção (Cupom)
# 9              Monitoramento Padrão

# %% [markdown]
# Essa tabela final seria então repassada para o time de marketing

# %%
df_resultado_final.to_csv('acoes_proximas_24h.csv', index=False)

# %% [markdown]
# # Conclusão Final: Modelo de Predição de Churn
#
# O objetivo deste projeto foi desenvolver um modelo de *Machine Learning* capaz de antecipar a evasão de clientes, permitindo ações preventivas de retenção. Após o processamento dos dados e a realização de testes estatísticos (como o **Teste de Tukey**), o algoritmo **Random Forest** foi selecionado como a melhor solução.
#
# ### 1. Decisão Estratégica: Da Técnica ao Negócio
# Embora o modelo tenha atingido um excelente poder de separação global ($AUC = 0.91$), a etapa final focou na **calibração operacional**.
#
# Em um cenário de Churn, o custo de perder um cliente (Falso Positivo) é significativamente superior ao custo de uma campanha de retenção direcionada (Falso Negativo). Por isso, optamos por um ajuste no limiar de decisão (*threshold*), priorizando a segurança da base de clientes.
#
# ### 2. Resultados Alcançados (Modelo Ajustado)
# Com o ajuste estratégico, o modelo final entregou os seguintes indicadores:
#
# * **Eficiência de Retenção (Especificidade):** Alcançamos **89,2%**, o que significa que quase 9 em cada 10 clientes que pretendem sair são identificados precocemente pelo modelo.
# * **Redução de Risco:** Conseguimos reduzir em **36%** o número de clientes que sairiam da base sem qualquer alerta prévio (Falsos Positivos caíram de 55 para 35).
# * **Equilíbrio Operacional:** Mesmo com o foco em Churn, o modelo mantém uma **Acurácia de 77,3%** e identifica corretamente **75%** dos clientes ativos.
#
# ### 3. Recomendações Operacionais
# Com base nos resultados, recomenda-se:
# 1.  **Integração com CRM:** Utilizar o modelo como um sistema de "Alerta Antecipado" para o time de CS (*Customer Success*).
# 2.  **Régua de Relacionamento:** Clientes classificados como "Churn" devem entrar automaticamente em fluxos de nutrição ou ofertas de fidelização.
# 3.  **Monitoramento:** Revisar o limiar periodicamente conforme o custo das campanhas de marketing mude, buscando sempre o melhor ROI entre retenção e gasto operacional.
